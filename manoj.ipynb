# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://pandeymannu54:Manoj1pandey@cluster0.l1av4a1.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)


## this is my database 
mydb = client["mydatabase"]

client.list_database_names()

#collection
mycol = mydb["myfirstcollection"]

#record
myfirstrecord = {"name": "manoj","lname": "pandey", "address": "haldwani"}

#insert record
x = mycol.insert_one(myfirstrecord)

mysecondrecord = {"movie": "avengers", "hero": "ironman", "director": "joss whedon"}

y = mycol.insert_one(mysecondrecord)

mythirdrecord = {"job": "developer", "company": "google", "location": "usa"}
z = mycol.insert_one(mythirdrecord)


multiplerecords = [{
"class":12, "section":"a", "rollno": 23} , 
{"class":11, "section":"b", "rollno": 24} , 
{"class":10, "section":"c", "rollno": 25},
{"class":9, "section":"d", "rollno": 26} , 
{"class":8, "section":"e", "rollno": 27} , 
{"class":7, "section":"f", "rollno": 28} , 
{"class":6, "section":"g", "rollno": 29} , 
{"class":5, "section":"h", "rollno": 30}]

a = mycol.insert_many(multiplerecords)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
client.list_database_names()
# Out:
# ['liveclass', 'mydatabase', 'sample_mflix', 'admin', 'local']

# %%
a.inserted_ids
# Out:
# [ObjectId('698db6bd225a2ac94c686cd6'),
#  ObjectId('698db6bd225a2ac94c686cd7'),
#  ObjectId('698db6bd225a2ac94c686cd8'),
#  ObjectId('698db6bd225a2ac94c686cd9'),
#  ObjectId('698db6bd225a2ac94c686cda'),
#  ObjectId('698db6bd225a2ac94c686cdb'),
#  ObjectId('698db6bd225a2ac94c686cdc'),
#  ObjectId('698db6bd225a2ac94c686cdd')]

# %%
multiplerecords = [{
"_id":1,"class":12, "section":"a", "rollno": 23} , 
{"_id":2,"class":11, "section":"b", "rollno": 24} , 
{"_id":3,"class":10, "section":"c", "rollno": 25},
{"class":9, "section":"d", "rollno": 26} , 
{"class":8, "section":"e", "rollno": 27} , 
{"class":7, "section":"f", "rollno": 28} , 
{"class":6, "section":"g", "rollno": 29} , 
{"class":5, "section":"h", "rollno": 30}]

# %%
b = mycol.insert_many(multiplerecords)

# %%
b.inserted_ids
# Out:
# [1,
#  2,
#  3,
#  ObjectId('698db6c2225a2ac94c686cde'),
#  ObjectId('698db6c2225a2ac94c686cdf'),
#  ObjectId('698db6c2225a2ac94c686ce0'),
#  ObjectId('698db6c2225a2ac94c686ce1'),
#  ObjectId('698db6c2225a2ac94c686ce2')]

# %%
mycol.find_one()
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'),
#  'name': 'manoj',
#  'lname': 'pandey',
#  'address': 'haldwani'}

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'), 'name': 'manoj', 'lname': 'pandey', 'address': 'haldwani'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd4'), 'movie': 'avengers', 'hero': 'ironman', 'director': 'joss whedon'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd5'), 'job': 'developer', 'company': 'google', 'location': 'usa'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd6'), 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': ObjectId('698db6bd225a2ac94c686cd7'), 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': ObjectId('698db6bd225a2ac94c686cd8'), 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6bd225a2ac94c686cd9'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6bd225a2ac94c686cda'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6bd225a2ac94c686cdb'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6bd225a2ac94c686cdc'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6bd225a2ac94c686cdd'), 'class': 5, 'section': 'h', 'rollno': 30}
# {'_id': 1, 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': 2, 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': 3, 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6c2225a2ac94c686cde'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6c2225a2ac94c686cdf'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6c2225a2ac94c686ce0'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6c2225a2ac94c686ce1'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6c2225a2ac94c686ce2'), 'class': 5, 'section': 'h', 'rollno': 30}

# %%
mycol.find_one({'name': 'manoj'})
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'),
#  'name': 'manoj',
#  'lname': 'pandey',
#  'address': 'haldwani'}

# %%
for x in mycol.find().sort("rollno" ):
    print(x)
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd4'), 'movie': 'avengers', 'hero': 'ironman', 'director': 'joss whedon'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd5'), 'job': 'developer', 'company': 'google', 'location': 'usa'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'), 'name': 'manoj', 'lname': 'pandey', 'address': 'haldwani'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd6'), 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': 1, 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': ObjectId('698db6bd225a2ac94c686cd7'), 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': 2, 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': ObjectId('698db6bd225a2ac94c686cd8'), 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': 3, 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6bd225a2ac94c686cd9'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6c2225a2ac94c686cde'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6bd225a2ac94c686cda'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6c2225a2ac94c686cdf'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6c2225a2ac94c686ce0'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6bd225a2ac94c686cdb'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6c2225a2ac94c686ce1'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6bd225a2ac94c686cdc'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6bd225a2ac94c686cdd'), 'class': 5, 'section': 'h', 'rollno': 30}
# {'_id': ObjectId('698db6c2225a2ac94c686ce2'), 'class': 5, 'section': 'h', 'rollno': 30}

# %%
myquery = {"movie": "avengers"}
new_values = {"$set": {"movie": "dhinkipapad"}}

# %%
mycol.update_one(myquery, new_values)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c7'), 'opTime': {'ts': Timestamp(1770899217, 3), 't': 199}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1770899217, 3), 'signature': {'hash': b'\xc1\x87\xe4G\xba\xdc\x86\x8e\xd5\xfc\xaa\xf2u\x16\xe3s\xda8\x06\xe8', 'keyId': 7542607375216148481}}, 'operationTime': Timestamp(1770899217, 3), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'), 'name': 'manoj', 'lname': 'pandey', 'address': 'haldwani'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd4'), 'movie': 'dhinkipapad', 'hero': 'ironman', 'director': 'joss whedon'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd5'), 'job': 'developer', 'company': 'google', 'location': 'usa'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd6'), 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': ObjectId('698db6bd225a2ac94c686cd7'), 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': ObjectId('698db6bd225a2ac94c686cd8'), 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6bd225a2ac94c686cd9'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6bd225a2ac94c686cda'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6bd225a2ac94c686cdb'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6bd225a2ac94c686cdc'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6bd225a2ac94c686cdd'), 'class': 5, 'section': 'h', 'rollno': 30}
# {'_id': 1, 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': 2, 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': 3, 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6c2225a2ac94c686cde'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6c2225a2ac94c686cdf'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6c2225a2ac94c686ce0'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6c2225a2ac94c686ce1'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6c2225a2ac94c686ce2'), 'class': 5, 'section': 'h', 'rollno': 30}

# %%
mycol.update_one({"name" : "manoj" , "lname" : "pandey"}, {"$set": {"name": "mpandey", 'lname' : "brahmin"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c7'), 'opTime': {'ts': Timestamp(1770899452, 2), 't': 199}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1770899452, 2), 'signature': {'hash': b'!-`|\x80\x08U\x95\x98\xcd-\xde\x9cg\xf0\x8c\x13\x1exu', 'keyId': 7542607375216148481}}, 'operationTime': Timestamp(1770899452, 2), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
     print(x)
# Out:
# {'_id': ObjectId('698db6bd225a2ac94c686cd3'), 'name': 'mpandey', 'lname': 'brahmin', 'address': 'haldwani'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd4'), 'movie': 'dhinkipapad', 'hero': 'ironman', 'director': 'joss whedon'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd5'), 'job': 'developer', 'company': 'google', 'location': 'usa'}
# {'_id': ObjectId('698db6bd225a2ac94c686cd6'), 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': ObjectId('698db6bd225a2ac94c686cd7'), 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': ObjectId('698db6bd225a2ac94c686cd8'), 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6bd225a2ac94c686cd9'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6bd225a2ac94c686cda'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6bd225a2ac94c686cdb'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6bd225a2ac94c686cdc'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6bd225a2ac94c686cdd'), 'class': 5, 'section': 'h', 'rollno': 30}
# {'_id': 1, 'class': 12, 'section': 'a', 'rollno': 23}
# {'_id': 2, 'class': 11, 'section': 'b', 'rollno': 24}
# {'_id': 3, 'class': 10, 'section': 'c', 'rollno': 25}
# {'_id': ObjectId('698db6c2225a2ac94c686cde'), 'class': 9, 'section': 'd', 'rollno': 26}
# {'_id': ObjectId('698db6c2225a2ac94c686cdf'), 'class': 8, 'section': 'e', 'rollno': 27}
# {'_id': ObjectId('698db6c2225a2ac94c686ce0'), 'class': 7, 'section': 'f', 'rollno': 28}
# {'_id': ObjectId('698db6c2225a2ac94c686ce1'), 'class': 6, 'section': 'g', 'rollno': 29}
# {'_id': ObjectId('698db6c2225a2ac94c686ce2'), 'class': 5, 'section': 'h', 'rollno': 30}

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/clead_google_playstore_data.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2               Art & Design   2018-08-01               1.2.4      4.0.3
# 3               Art & Design   2018-06-08  Varies with device        4.2
# 4    Art & Design;Creativity   2018-06-20                 1.1        4.4
#
#    day  month  year
# 0    7      1  2018
# 1   15      1  2018
# 2    1      8  2018
# 3    8      6  2018
# 4   20      6  2018

# %%
len(df.columns)
# Out:
# 16

# %%
## this is the my database

mydb = client["mydatabase"]

# %%
mycol2 = mydb["mysecondcollection"]

# %%
a = df.T.to_json()

# %%
import json

#load the record 
records = json.loads(a)

# %%
#list of records 

listofrecords = records.values()
listofrecords
# Out:
genres': 'Art & Design', 'Last Updated': '2017-09-20', 'Current Ver': '2.9.2', 'Android Ver': '3.0 ', 'day': 20, 'month': 9, 'year': 2017}, {'App': 'Kids Paint Free - Drawing Fun', 'Category': 'ART_AND_DESIGN', 'Rating': 4.7, 'Reviews': 121, 'Size': 3100.0, 'Installs': 10000, 'Type': 'Free', 'Price': 0.0, 'Content Rating': 'Everyone', 'Genres': 'Art & Design;Creativity', 'Last Updated': '2018-07-03', 'Current Ver': '2.8', 'Android Ver': '4.0.3 ', 'day': 3, 'month': 7, 'year': 2018}, {'App': 'Text on Photo - Fonteee', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 13880, 'Size': 28000.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Content Rating': 'Everyone', 'Genres': 'Art & Design', 'Last Updated': '2017-10-27', 'Current Ver': '1.0.4', 'Android Ver': '4.1 ', 'day': 27, 'month': 10, 'year': 2017}, {'App': 'Name Art Photo Editor - Focus n Filters', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 8788, 'Size': 12000.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Con ...

# %%
mycol2.insert_many(listofrecords)
# Out:
# InsertManyResult([ObjectId('698dd7b6225a2ac94c686ce3'), ObjectId('698dd7b6225a2ac94c686ce4'), ObjectId('698dd7b6225a2ac94c686ce5'), ObjectId('698dd7b6225a2ac94c686ce6'), ObjectId('698dd7b6225a2ac94c686ce7'), ObjectId('698dd7b6225a2ac94c686ce8'), ObjectId('698dd7b6225a2ac94c686ce9'), ObjectId('698dd7b6225a2ac94c686cea'), ObjectId('698dd7b6225a2ac94c686ceb'), ObjectId('698dd7b6225a2ac94c686cec'), ObjectId('698dd7b6225a2ac94c686ced'), ObjectId('698dd7b6225a2ac94c686cee'), ObjectId('698dd7b6225a2ac94c686cef'), ObjectId('698dd7b6225a2ac94c686cf0'), ObjectId('698dd7b6225a2ac94c686cf1'), ObjectId('698dd7b6225a2ac94c686cf2'), ObjectId('698dd7b6225a2ac94c686cf3'), ObjectId('698dd7b6225a2ac94c686cf4'), ObjectId('698dd7b6225a2ac94c686cf5'), ObjectId('698dd7b6225a2ac94c686cf6'), ObjectId('698dd7b6225a2ac94c686cf7'), ObjectId('698dd7b6225a2ac94c686cf8'), ObjectId('698dd7b6225a2ac94c686cf9'), ObjectId('698dd7b6225a2ac94c686cfa'), ObjectId('698dd7b6225a2ac94c686cfb'), ObjectId('698dd7b6225a2ac94c686cfc'), ObjectId('698dd7b6225a2ac94c686cfd'), ObjectId('698dd7b6225a2ac94c686cfe'), ObjectId('698dd7b6225a2ac94c686cff'), ObjectId('698dd7b6225a2ac94c686d00'), ObjectId('698dd7b6225a2ac94c686d01'), ObjectId('698dd7b6225a2ac94c686d02'), ObjectId('698dd7b6225a2ac94c686d03'), ObjectId('698dd7b6225a2ac94c686d04'), ObjectId('698dd7b6225a2ac94c686d05'), ObjectId('698dd7b6225a2ac94c686d06'), ObjectId('698dd7b6225a2ac94c686d07'), ObjectId('698dd7b6225a2ac94c686d08'), ObjectId('698dd7b6225a2ac94c686d09'), ObjectId('698dd7b6225a2ac94c686d