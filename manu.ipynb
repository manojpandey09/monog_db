# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://pandeymannu54:Manoj1pandey@cluster0.l1av4a1.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mydb = client["mannudatabase"]

# %%
first_collection = mydb["manojcollection"]

# %%
myfirstdocument=[{"name":"manoj", "age": 22 , "city": "haldwani" , "salary":50000} , {"id": 32443 , "name": "manu", "age": 2, "city": "ninitall", "salary": 100000}]

# %%
a = first_collection.insert_many(myfirstdocument)

# %%
client.list_database_names()
# Out:
# ['liveclass', 'mannudatabase', 'mydatabase', 'sample_mflix', 'admin', 'local']

# %%
a.inserted_ids
# Out:
# [ObjectId('698eb8b99cd934aab3379596'), ObjectId('698eb8b99cd934aab3379597')]

# %%
multiplerecords = [{
"_id":1,"class":12, "section":"a", "rollno": 23} , 
{"_id":2,"class":11, "section":"b", "rollno": 24} , 
{"_id":3,"class":10, "section":"c", "rollno": 25},
{"class":9, "section":"d", "rollno": 26} , 
{"class":8, "section":"e", "rollno": 27} , 
{"class":7, "section":"f", "rollno": 28} , 
{"class":6, "section":"g", "rollno": 29} , 
{"class":5, "section":"h", "rollno": 30}]

# %%
b = first_collection.insert_many(multiplerecords)

# %%
b.inserted_ids
# Out:
# [1,
#  2,
#  3,
#  ObjectId('698ebb959cd934aab3379598'),
#  ObjectId('698ebb959cd934aab3379599'),
#  ObjectId('698ebb959cd934aab337959a'),
#  ObjectId('698ebb959cd934aab337959b'),
#  ObjectId('698ebb959cd934aab337959c')]

# %%
import pandas as pd

# %%
df =pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/clead_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
my = client["filedatabase"]

# %%
collection = my["filecollection"]

# %%
d = df.T.to_json()

# %%
import json
record = json.loads(d)

# %%
nowvalue = record.values()

# %%
collection.insert_many(nowvalue)
# Out:
# InsertManyResult([ObjectId('698ebf3f9cd934aab337959d'), ObjectId('698ebf3f9cd934aab337959e'), ObjectId('698ebf3f9cd934aab337959f'), ObjectId('698ebf3f9cd934aab33795a0'), ObjectId('698ebf3f9cd934aab33795a1'), ObjectId('698ebf3f9cd934aab33795a2'), ObjectId('698ebf3f9cd934aab33795a3'), ObjectId('698ebf3f9cd934aab33795a4'), ObjectId('698ebf3f9cd934aab33795a5'), ObjectId('698ebf3f9cd934aab33795a6'), ObjectId('698ebf3f9cd934aab33795a7'), ObjectId('698ebf3f9cd934aab33795a8'), ObjectId('698ebf3f9cd934aab33795a9'), ObjectId('698ebf3f9cd934aab33795aa'), ObjectId('698ebf3f9cd934aab33795ab'), ObjectId('698ebf3f9cd934aab33795ac'), ObjectId('698ebf3f9cd934aab33795ad'), ObjectId('698ebf3f9cd934aab33795ae'), ObjectId('698ebf3f9cd934aab33795af'), ObjectId('698ebf3f9cd934aab33795b0'), ObjectId('698ebf3f9cd934aab33795b1'), ObjectId('698ebf3f9cd934aab33795b2'), ObjectId('698ebf3f9cd934aab33795b3'), ObjectId('698ebf3f9cd934aab33795b4'), ObjectId('698ebf3f9cd934aab33795b5'), ObjectId('698ebf3f9cd934aab337
# ...
